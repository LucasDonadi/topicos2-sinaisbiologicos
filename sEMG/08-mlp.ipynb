# %% [markdown]
# ## Aplicando *Multilayer Perceptron*
#
# Está demonstrado neste ponto a execução de um Multilayer Perceptron (MLP) utilizando o framework para construção e execução de Redes Neurais Artificias (RNN) Keras.
#
# Vamos iniciar mostrando como carregar uma base de dados da UCI e utilizar o classificador ID3 obtido por meio scikit learn. A base de dados é a Car Evaluation Data Set (https://archive.ics.uci.edu/ml/datasets/Car+Evaluation).
#
# O dataset possui os seguintes atributos:
#
# - buying: vhigh, high, med, low.
# - maint: vhigh, high, med, low.
# - doors: 2, 3, 4, 5more.
# - persons: 2, 4, more.
# - lug_boot: small, med, big.
# - safety: low, med, high.
# E as seguintes classes: unacc, acc, good, vgood
#
# ### Definição de todas as bibliotecas

# %%
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
from keras.utils.np_utils import to_categorical
import numpy as np
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import LabelEncoder
from urllib.request import urlopen, urlretrieve

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Código para o carregamento da base de dados
#
# Após o carregamento dos dados, é utilizado a função LabelEncoder para transformar os dados de categóricos para numéricos.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data'
urlretrieve(url, 'car.txt')
filedata = open('car.txt')
data = filedata.read()
dataset = np.array([s.split(',') for s in data.split('\n')][:-1])
print(dataset)
print(len(dataset))
print(dataset.shape)

# Transformação dos valores de categórico para numérico
le = LabelEncoder()
features = np.array([le.fit_transform(f) for f in dataset[:, :-1].T]).T

# obtendo a coluna com as respostas
labels = le.fit_transform(dataset[:, -1])
categorical_labels = to_categorical(labels, num_classes=len(set(labels)))
# Out:
# [['vhigh' 'vhigh' '2' ... 'small' 'low' 'unacc']
#  ['vhigh' 'vhigh' '2' ... 'small' 'med' 'unacc']
#  ['vhigh' 'vhigh' '2' ... 'small' 'high' 'unacc']
#  ...
#  ['low' 'low' '5more' ... 'big' 'low' 'unacc']
#  ['low' 'low' '5more' ... 'big' 'med' 'good']
#  ['low' 'low' '5more' ... 'big' 'high' 'vgood']]
# 1728
# (1728, 7)

# %% [markdown]
# ### Desenvolvimento da função para plotar os custos e as acurácias:

# %%
def plot_history(h):
    loss_list = [s for s in h.history.keys() if 'loss' in s and 'val' not in s]
    val_loss_list = [s for s in h.history.keys() if 'loss' in s and 'val' in s]
    acc_list = [s for s in h.history.keys() if 'acc' in s and 'val' not in s]
    val_acc_list = [s for s in h.history.keys() if 'acc' in s and 'val' in s]
    if len(loss_list) == 0:
        print('Custo não está presente no histórico')
        return
    epochs = range(1, len(history.history[loss_list[0]]) + 1)
    # Custo
    plt.figure(1)
    for l in loss_list:
        plt.plot(epochs, h.history[l], 'b',
                 label='Custo [treinamento] (' + str(str(format(
                    h.history[l][-1],'.5f'))+')'))
    for l in val_loss_list:
        plt.plot(epochs, h.history[l], 'g',
                 label='Custo [validação] (' + str(str(format(
                    h.history[l][-1],'.5f'))+')'))
    plt.title('Custo')
    plt.xlabel('Épocas')
    plt.ylabel('Custo')
    plt.legend()
    # Acurácia
    plt.figure(2)
    for l in acc_list:
        plt.plot(epochs, h.history[l], 'b',
                 label='Acurácia [treinamento] (' + str(format(
                    h.history[l][-1],'.5f'))+')')
    for l in val_acc_list:
        plt.plot(epochs, h.history[l], 'g',
                 label='Acurácia [validação] (' + str(format(
                    h.history[l][-1],'.5f'))+')')
    plt.title('Acurácia')
    plt.xlabel('Épocas')
    plt.ylabel('Acurácia')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Divisão dos dados em treino e teste:

# %%
# Dividindo em conjuntos de treino (80%) e teste (20%)
X_train, X_test, y_train, y_test = train_test_split(
    features, categorical_labels, test_size=0.3)

# treino: 80% dos 80% de treino. teste: 20% dos 80% de treino.
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.3, shuffle=True)

# %% [markdown]
# ### Aplicação do algoritmo de MLP e geração dos resultados:

# %%
# definição de uma fração do regularizador
l = 0.01

# desenvolvimento do modelo Keras para uma MLP
model = Sequential()
model.add(Dense(20, activation='relu', input_dim=6,
                kernel_regularizer=regularizers.l2(l)))
# Aplicação de um dropout (caso necessário)
# model.add(Dropout(0.5))
model.add(Dense(10, activation='relu',
                kernel_regularizer=regularizers.l2(l)))
# Aplicação de um dropout (caso necessário)
# model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

# Aplicação de um modelo de descida de gradiente utilizando o Stocastic Gradient Descendent (SGD)
sgd = SGD(lr=0.05, momentum=0.0)
# Função de otimização da rede: ADAM
adam = Adam(lr=0.005, beta_1=0.9, beta_2=0.999)
# Função de custo baseada em dados originalmente categóricos
model.compile(loss='categorical_crossentropy', optimizer=adam,
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=150, batch_size=15,
                    validation_data=(X_val, y_val))
plot_history(history)
score = model.predict_classes(X_test)
y_true = [np.where(x == 1)[0][0] for x in y_test]
print('Acurácia: %0.2f%%' % (accuracy_score(y_true, score) * 100))
print('Matriz de confusão:')
print(confusion_matrix(y_true, score))
print()
print(classification_report(y_true, score, digits=5))
# Out:
# Epoch 1/150
# c:\Users\mathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\optimizers\legacy\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# c:\Users\mathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\optimizers\legacy\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 57/57 [==============================] - 1s 5ms/step - loss: 1.0737 - accuracy: 0.6560 - val_loss: 0.8423 - val_accuracy: 0.7328
# Epoch 2/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8987 - accuracy: 0.6868 - val_loss: 0.7410 - val_accuracy: 0.7273
# Epoch 3/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8124 - accuracy: 0.6915 - val_loss: 0.7184 - val_accuracy: 0.7273
# Epoch 4/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.7710 - accuracy: 0.6927 - val_loss: 0.6925 - val_accuracy: 0.7493
# Epoch 5/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.7345 - accuracy: 0.6927 - val_loss: 0.6571 - val_accuracy: 0.7493
# Epoch 6/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7038 - accuracy: 0.7340 - val_loss: 0.6186 - val_accuracy: 0.7713
# Epoch 7/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6591 - accuracy: 0.7589 - val_loss: 0.6206 - val_accuracy: 0.8375
# Epoch 8/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6159 - accuracy: 0.7943 - val_loss: 0.5593 - val_accuracy: 0.8457
# Epoch 9/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5880 - accuracy: 0.8109 - val_loss: 0.5318 - val_accuracy: 0.8567
# Epoch 10/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5730 - accuracy: 0.8191 - val_loss: 0.5242 - val_accuracy: 0.8595
# Epoch 11/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5496 - accuracy: 0.8274 - val_loss: 0.5166 - val_accuracy: 0.8567
# Epoch 12/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5596 - accuracy: 0.8061 - val_loss: 0.5015 - val_accuracy: 0.8623
# Epoch 13/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5171 - accuracy: 0.8404 - val_loss: 0.4901 - val_accuracy: 0.8815
# Epoch 14/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5054 - accuracy: 0.8499 - val_loss: 0.4689 - val_accuracy: 0.8512
# Epoch 15/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4826 - accuracy: 0.8641 - val_loss: 0.4683 - val_accuracy: 0.8733
# Epoch 16/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5114 - accuracy: 0.8440 - val_loss: 0.5097 - val_accuracy: 0.8595
# Epoch 17/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4696 - accuracy: 0.8759 - val_loss: 0.4566 - val_accuracy: 0.8815
# Epoch 18/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4933 - accuracy: 0.8593 - val_loss: 0.5409 - val_accuracy: 0.8485
# Epoch 19/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4617 - accuracy: 0.8818 - val_loss: 0.4279 - val_accuracy: 0.8981
# Epoch 20/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.8818 - val_loss: 0.4290 - val_accuracy: 0.9036
# Epoch 21/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4328 - accuracy: 0.8972 - val_loss: 0.4283 - val_accuracy: 0.9008
# Epoch 22/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4281 - accuracy: 0.8889 - val_loss: 0.4490 - val_accuracy: 0.8678
# Epoch 23/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.8830 - val_loss: 0.4315 - val_accuracy: 0.8788
# Epoch 24/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.8747 - val_loss: 0.4101 - val_accuracy: 0.9063
# Epoch 25/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4137 - accuracy: 0.8936 - val_loss: 0.4373 - val_accuracy: 0.8815
# Epoch 26/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4000 - accuracy: 0.9090 - val_loss: 0.4060 - val_accuracy: 0.9008
# Epoch 27/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4052 - accuracy: 0.9078 - val_loss: 0.3720 - val_accuracy: 0.9174
# Epoch 28/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3986 - accuracy: 0.9019 - val_loss: 0.3630 - val_accuracy: 0.9201
# Epoch 29/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.9149 - val_loss: 0.3733 - val_accuracy: 0.9118
# Epoch 30/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3804 - accuracy: 0.9125 - val_loss: 0.3837 - val_accuracy: 0.9063
# Epoch 31/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4092 - accuracy: 0.8830 - val_loss: 0.3575 - val_accuracy: 0.9229
# Epoch 32/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3760 - accuracy: 0.9208 - val_loss: 0.3505 - val_accuracy: 0.9311
# Epoch 33/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.9196 - val_loss: 0.3460 - val_accuracy: 0.9366
# Epoch 34/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3576 - accuracy: 0.9279 - val_loss: 0.3708 - val_accuracy: 0.9421
# Epoch 35/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3577 - accuracy: 0.9291 - val_loss: 0.3408 - val_accuracy: 0.9366
# Epoch 36/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3595 - accuracy: 0.9314 - val_loss: 0.3695 - val_accuracy: 0.9118
# Epoch 37/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3710 - accuracy: 0.9161 - val_loss: 0.3557 - val_accuracy: 0.9174
# Epoch 38/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3728 - accuracy: 0.9113 - val_loss: 0.3492 - val_accuracy: 0.9256
# Epoch 39/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3621 - accuracy: 0.9232 - val_loss: 0.3425 - val_accuracy: 0.9256
# Epoch 40/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3551 - accuracy: 0.9291 - val_loss: 0.3451 - val_accuracy: 0.9256
# Epoch 41/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3634 - accuracy: 0.9161 - val_loss: 0.3281 - val_accuracy: 0.9532
# Epoch 42/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3444 - accuracy: 0.9314 - val_loss: 0.3247 - val_accuracy: 0.9311
# Epoch 43/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.9362 - val_loss: 0.3326 - val_accuracy: 0.9284
# Epoch 44/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3358 - accuracy: 0.9362 - val_loss: 0.3138 - val_accuracy: 0.9477
# Epoch 45/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3356 - accuracy: 0.9326 - val_loss: 0.3720 - val_accuracy: 0.9174
# Epoch 46/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3421 - accuracy: 0.9314 - val_loss: 0.3714 - val_accuracy: 0.9146
# Epoch 47/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3448 - accuracy: 0.9173 - val_loss: 0.4035 - val_accuracy: 0.8871
# Epoch 48/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3335 - accuracy: 0.9409 - val_loss: 0.3096 - val_accuracy: 0.9394
# Epoch 49/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.9326 - val_loss: 0.3054 - val_accuracy: 0.9449
# Epoch 50/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3188 - accuracy: 0.9456 - val_loss: 0.2996 - val_accuracy: 0.9559
# Epoch 51/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3252 - accuracy: 0.9326 - val_loss: 0.3019 - val_accuracy: 0.9559
# Epoch 52/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3342 - accuracy: 0.9279 - val_loss: 0.3323 - val_accuracy: 0.9256
# Epoch 53/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3130 - accuracy: 0.9374 - val_loss: 0.3107 - val_accuracy: 0.9449
# Epoch 54/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3015 - accuracy: 0.9504 - val_loss: 0.3130 - val_accuracy: 0.9449
# Epoch 55/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3147 - accuracy: 0.9444 - val_loss: 0.3106 - val_accuracy: 0.9449
# Epoch 56/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3226 - accuracy: 0.9303 - val_loss: 0.3013 - val_accuracy: 0.9504
# Epoch 57/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2996 - accuracy: 0.9527 - val_loss: 0.2952 - val_accuracy: 0.9504
# Epoch 58/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3003 - accuracy: 0.9492 - val_loss: 0.3079 - val_accuracy: 0.9449
# Epoch 59/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3098 - accuracy: 0.9362 - val_loss: 0.3038 - val_accuracy: 0.9366
# Epoch 60/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2989 - accuracy: 0.9444 - val_loss: 0.2887 - val_accuracy: 0.9504
# Epoch 61/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3017 - accuracy: 0.9444 - val_loss: 0.2827 - val_accuracy: 0.9614
# Epoch 62/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3059 - accuracy: 0.9480 - val_loss: 0.2804 - val_accuracy: 0.9559
# Epoch 63/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2963 - accuracy: 0.9492 - val_loss: 0.2838 - val_accuracy: 0.9504
# Epoch 64/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2871 - accuracy: 0.9527 - val_loss: 0.2776 - val_accuracy: 0.9477
# Epoch 65/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2852 - accuracy: 0.9551 - val_loss: 0.2858 - val_accuracy: 0.9532
# Epoch 66/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3058 - accuracy: 0.9444 - val_loss: 0.3326 - val_accuracy: 0.9311
# Epoch 67/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2888 - accuracy: 0.9504 - val_loss: 0.2766 - val_accuracy: 0.9559
# Epoch 68/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2858 - accuracy: 0.9551 - val_loss: 0.2635 - val_accuracy: 0.9725
# Epoch 69/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2869 - accuracy: 0.9527 - val_loss: 0.2873 - val_accuracy: 0.9614
# Epoch 70/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2777 - accuracy: 0.9645 - val_loss: 0.2760 - val_accuracy: 0.9504
# Epoch 71/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2777 - accuracy: 0.9492 - val_loss: 0.3246 - val_accuracy: 0.9284
# Epoch 72/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2819 - accuracy: 0.9551 - val_loss: 0.2640 - val_accuracy: 0.9587
# Epoch 73/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2820 - accuracy: 0.9622 - val_loss: 0.2637 - val_accuracy: 0.9614
# Epoch 74/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2857 - accuracy: 0.9433 - val_loss: 0.2940 - val_accuracy: 0.9504
# Epoch 75/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2776 - accuracy: 0.9634 - val_loss: 0.2657 - val_accuracy: 0.9559
# Epoch 76/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2721 - accuracy: 0.9563 - val_loss: 0.3421 - val_accuracy: 0.9091
# Epoch 77/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2695 - accuracy: 0.9634 - val_loss: 0.2784 - val_accuracy: 0.9449
# Epoch 78/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2770 - accuracy: 0.9539 - val_loss: 0.2628 - val_accuracy: 0.9642
# Epoch 79/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2650 - accuracy: 0.9634 - val_loss: 0.2626 - val_accuracy: 0.9614
# Epoch 80/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2604 - accuracy: 0.9598 - val_loss: 0.2712 - val_accuracy: 0.9532
# Epoch 81/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2551 - accuracy: 0.9645 - val_loss: 0.2548 - val_accuracy: 0.9697
# Epoch 82/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2654 - accuracy: 0.9574 - val_loss: 0.2437 - val_accuracy: 0.9614
# Epoch 83/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2671 - accuracy: 0.9504 - val_loss: 0.2759 - val_accuracy: 0.9532
# Epoch 84/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2670 - accuracy: 0.9598 - val_loss: 0.2523 - val_accuracy: 0.9614
# Epoch 85/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2615 - accuracy: 0.9586 - val_loss: 0.2465 - val_accuracy: 0.9725
# Epoch 86/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2692 - accuracy: 0.9563 - val_loss: 0.2725 - val_accuracy: 0.9559
# Epoch 87/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 0.9610 - val_loss: 0.2771 - val_accuracy: 0.9477
# Epoch 88/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2592 - accuracy: 0.9634 - val_loss: 0.2508 - val_accuracy: 0.9642
# Epoch 89/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2515 - accuracy: 0.9634 - val_loss: 0.2454 - val_accuracy: 0.9697
# Epoch 90/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.9586 - val_loss: 0.2568 - val_accuracy: 0.9614
# Epoch 91/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2429 - accuracy: 0.9716 - val_loss: 0.2337 - val_accuracy: 0.9642
# Epoch 92/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2429 - accuracy: 0.9681 - val_loss: 0.3456 - val_accuracy: 0.9008
# Epoch 93/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2546 - accuracy: 0.9574 - val_loss: 0.2455 - val_accuracy: 0.9669
# Epoch 94/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2592 - accuracy: 0.9468 - val_loss: 0.3266 - val_accuracy: 0.9256
# Epoch 95/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2378 - accuracy: 0.9740 - val_loss: 0.2350 - val_accuracy: 0.9669
# Epoch 96/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2464 - accuracy: 0.9645 - val_loss: 0.2389 - val_accuracy: 0.9669
# Epoch 97/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2477 - accuracy: 0.9681 - val_loss: 0.2475 - val_accuracy: 0.9642
# Epoch 98/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2820 - accuracy: 0.9397 - val_loss: 0.2436 - val_accuracy: 0.9614
# Epoch 99/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2416 - accuracy: 0.9681 - val_loss: 0.2312 - val_accuracy: 0.9725
# Epoch 100/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2450 - accuracy: 0.9645 - val_loss: 0.2748 - val_accuracy: 0.9532
# Epoch 101/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2344 - accuracy: 0.9669 - val_loss: 0.2287 - val_accuracy: 0.9725
# Epoch 102/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2573 - accuracy: 0.9527 - val_loss: 0.2942 - val_accuracy: 0.9256
# Epoch 103/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.9704 - val_loss: 0.2390 - val_accuracy: 0.9642
# Epoch 104/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9811 - val_loss: 0.2243 - val_accuracy: 0.9669
# Epoch 105/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2179 - accuracy: 0.9775 - val_loss: 0.2304 - val_accuracy: 0.9642
# Epoch 106/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2214 - accuracy: 0.9728 - val_loss: 0.2302 - val_accuracy: 0.9752
# Epoch 107/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2247 - accuracy: 0.9740 - val_loss: 0.2243 - val_accuracy: 0.9642
# Epoch 108/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9787 - val_loss: 0.2251 - val_accuracy: 0.9669
# Epoch 109/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2223 - accuracy: 0.9740 - val_loss: 0.2366 - val_accuracy: 0.9752
# Epoch 110/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2209 - accuracy: 0.9775 - val_loss: 0.2377 - val_accuracy: 0.9587
# Epoch 111/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2271 - accuracy: 0.9693 - val_loss: 0.2286 - val_accuracy: 0.9669
# Epoch 112/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2588 - accuracy: 0.9539 - val_loss: 0.2214 - val_accuracy: 0.9642
# Epoch 113/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2212 - accuracy: 0.9645 - val_loss: 0.2292 - val_accuracy: 0.9587
# Epoch 114/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2384 - accuracy: 0.9634 - val_loss: 0.2228 - val_accuracy: 0.9780
# Epoch 115/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.9645 - val_loss: 0.2222 - val_accuracy: 0.9642
# Epoch 116/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2111 - accuracy: 0.9775 - val_loss: 0.2087 - val_accuracy: 0.9807
# Epoch 117/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2274 - accuracy: 0.9669 - val_loss: 0.2162 - val_accuracy: 0.9669
# Epoch 118/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2176 - accuracy: 0.9728 - val_loss: 0.2224 - val_accuracy: 0.9780
# Epoch 119/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2192 - accuracy: 0.9716 - val_loss: 0.2174 - val_accuracy: 0.9669
# Epoch 120/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2183 - accuracy: 0.9716 - val_loss: 0.2026 - val_accuracy: 0.9752
# Epoch 121/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2109 - accuracy: 0.9811 - val_loss: 0.2059 - val_accuracy: 0.9752
# Epoch 122/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2054 - accuracy: 0.9835 - val_loss: 0.2164 - val_accuracy: 0.9642
# Epoch 123/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2082 - accuracy: 0.9764 - val_loss: 0.2233 - val_accuracy: 0.9642
# Epoch 124/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9799 - val_loss: 0.2171 - val_accuracy: 0.9614
# Epoch 125/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2060 - accuracy: 0.9764 - val_loss: 0.2096 - val_accuracy: 0.9752
# Epoch 126/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2115 - accuracy: 0.9693 - val_loss: 0.1990 - val_accuracy: 0.9835
# Epoch 127/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 0.9870 - val_loss: 0.1920 - val_accuracy: 0.9862
# Epoch 128/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2060 - accuracy: 0.9811 - val_loss: 0.2012 - val_accuracy: 0.9780
# Epoch 129/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1962 - accuracy: 0.9882 - val_loss: 0.2004 - val_accuracy: 0.9780
# Epoch 130/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2086 - accuracy: 0.9787 - val_loss: 0.1943 - val_accuracy: 0.9807
# Epoch 131/150
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1979 - accuracy: 0.9799 - val_loss: 0.2671 - val_accuracy: 0.9477
# Epoch 132/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2106 - accuracy: 0.9704 - val_loss: 0.1975 - val_accuracy: 0.9780
# Epoch 133/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2056 - accuracy: 0.9728 - val_loss: 0.1863 - val_accuracy: 0.9835
# Epoch 134/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.9764 - val_loss: 0.1920 - val_accuracy: 0.9862
# Epoch 135/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2070 - accuracy: 0.9716 - val_loss: 0.2182 - val_accuracy: 0.9614
# Epoch 136/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2014 - accuracy: 0.9775 - val_loss: 0.1953 - val_accuracy: 0.9862
# Epoch 137/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 0.9835 - val_loss: 0.2198 - val_accuracy: 0.9669
# Epoch 138/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1903 - accuracy: 0.9882 - val_loss: 0.2135 - val_accuracy: 0.9697
# Epoch 139/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1874 - accuracy: 0.9858 - val_loss: 0.2080 - val_accuracy: 0.9642
# Epoch 140/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1912 - accuracy: 0.9787 - val_loss: 0.1999 - val_accuracy: 0.9780
# Epoch 141/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2179 - accuracy: 0.9634 - val_loss: 0.3171 - val_accuracy: 0.9036
# Epoch 142/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2092 - accuracy: 0.9693 - val_loss: 0.1864 - val_accuracy: 0.9835
# Epoch 143/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2007 - accuracy: 0.9752 - val_loss: 0.1913 - val_accuracy: 0.9780
# Epoch 144/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2052 - accuracy: 0.9775 - val_loss: 0.1868 - val_accuracy: 0.9725
# Epoch 145/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1935 - accuracy: 0.9823 - val_loss: 0.1937 - val_accuracy: 0.9725
# Epoch 146/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1896 - accuracy: 0.9823 - val_loss: 0.1906 - val_accuracy: 0.9780
# Epoch 147/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1843 - accuracy: 0.9835 - val_loss: 0.2355 - val_accuracy: 0.9614
# Epoch 148/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1834 - accuracy: 0.9894 - val_loss: 0.1794 - val_accuracy: 0.9725
# Epoch 149/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1901 - accuracy: 0.9858 - val_loss: 0.2271 - val_accuracy: 0.9477
# Epoch 150/150
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 0.9787 - val_loss: 0.1832 - val_accuracy: 0.9807
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 27
#      24 history = model.fit(X_train, y_train, epochs=150, batch_size=15,
#      25                     validation_data=(X_val, y_val))
#      26 plot_history(history)
# ---> 27 score = model.predict_classes(X_test)
#      28 y_true = [np.where(x == 1)[0][0] for x in y_test]
#      29 print('Acurácia: %0.2f%%' % (accuracy_score(y_true, score) * 100))
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %% [markdown]
# **Desafio:** "Encaixar" o classificador MLP no no *dataset* criado durante a disciplina.
